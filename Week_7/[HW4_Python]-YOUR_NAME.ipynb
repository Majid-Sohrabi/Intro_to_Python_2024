# %% [markdown]
# # Homework 4 - Python
#
# First Name:
#
# Last Name:
#
# Group:

# %% [markdown]
# ## Task 1  - Sorting (1 point)
#
# 1) Print exams' and its dates in alphabetical order (A -> Z) by the name of the course.
# 2) Print exams' and its dates in reversed alphabetical order (Z -> A) by the name of the course.
# 3) Print exams and its dates in chronological order from the earliest to the latest.
# 4) Print exams and its dates in chronological order from the latest to the earliest.
# 5) Display the earliest exam's date and its course name.
# 6) Display the latest exam's date and its course name.
# 7) For each date print the exams that will be held on this day. If there are several exams, print then in alphabetical order. E.g.
#
# ```
# 21-06-2022
# Chinese
# Japanese
# Korean
# 25-06-2002
# English
# ```

# %%
exam_dates = {'Economics': '18-06-2022',
              'Japanese': '21-06-2022',
              'Korean': '21-06-2022',
              'Chinese': '21-06-2022',
              'English': '25-06-2022',
              'Programming in Python': '27-06-2022',
              'Regional Studies': '28-07-2022'}

# %%
<YOUR CODE>

# %% [markdown]
# ## Task 2 - Stadium Are (1 point)
#
# A football stadium has the shape as shown in below Figure.
#
# ![stadium.PNG](data:image/png;base64,...)
#
#
# The total area of the stadium comprises of 3 parts indicating by **area_1, area_2 and area_3** in the figure. **area_1 and area_3 are half-circles** whose diameters are **q**. **area_2 is a rectangle of size p by q**.
#
#
# Your task is to write a program that prints out the total area of a stadium given the value of p and q. Your program starts by reading in values of p and q on a separate lines from the console. Here is an example input.
#
# > Enter p: 10.2 \
# > Enter q: 15.0
#
# This means p is 10.2 and q is 15.0. The expected output should be formatted as follows:\
# ```
# The total area is 329.625
# ```
# When we grade your program, we will change the values of p and q so it is important that your
# program should work for any values of p and q.
#
# **Note:** You may assume that the value of π = 3.14

# %%
<YOUR CODE>

# %% [markdown]
# ## Task 3 - Shipping Box Selection (1 point)
#
# Your task is to create a Python program to assist an e-commerce company in determining the ideal shipping box for items sold online. The program should:
#
#
#
# 1.   Prompt the user to input the dimensions (length, width, and height in cm) of the item.
# 2.   Calculate the minimum volume required for safe packaging, considering a 10% buffer space for packaging material.
#
# 1.   Determine the most suitable shipping box from a predefined list based on the calculated volume.
# 2.   Display the recommended box type along with its dimensions.
#
# The available box types and their dimensions are predefined as below.
#
# - **Letter / Document: Dimensions:** 23 cm x 33 cm x 2 cm (Standard A4 envelope size)
# - **Small Box: Dimensions:** 15 cm x 15 cm x 15 cm
# - **Medium Box: Dimensions:** 30 cm x 30 cm x 30 cm
# - **Large Box: Dimensions:** 40 cm x 40 cm x 40 cm
# - **Cargo: Dimensions:** 60 cm x 60 cm x 60 cm

# %%
<YOUR CODE>

# %% [markdown]
# ## Task 4 - Multiplication Table (1 point)
#
# Write a Python program that displays a multiplication table that looks like this:
#
# ![table.PNG](data:image/png;base64,...)

# %%
<YOUR CODE>

# %% [markdown]
# ## Task 5 - Validate Date  (1 point)
#
# Develop a Python function called **isValidDate(year, month, day)** that takes three integers as input representing a *year, month, and day*, respectively. The function should return **True** if the provided integers represent a valid date and **False** otherwise.
#
# Guidelines:
#
#
# 1.   Ensure that the month is within the range 1 to 12, otherwise return **False**.
#
# 2.   Check if the day is within the valid range for the given month:
#
# *   For months 4, 6, 9 or 11, the maximum day is 30.
# *   For February (month 2), the maximum day is 28 (or 29 on leap years), If it's a leap year and February has 29 days, return **True**.
# *   For all other months, the maximum day is 31.
# *   Return False otherwise.
#
#
#
# > Example
#
# *   isValidDate(1999, 12, 31) == True
# *   isValidDate(2029, 13, 1) == False ( There is no 13th Month in calendar)

# %%
<YOUR CODE>
